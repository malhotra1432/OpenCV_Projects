# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('./img.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[ 78,  71,  92],
#         [ 84,  77,  98],
#         [ 82,  75,  96],
#         ...,
#         [ 89, 130, 169],
#         [ 87, 128, 167],
#         [ 84, 125, 164]],
#
#        [[ 80,  73,  94],
#         [ 85,  78,  99],
#         [ 83,  76,  97],
#         ...,
#         [ 89, 129, 171],
#         [ 90, 128, 170],
#         [ 85, 125, 167]],
#
#        [[ 70,  63,  84],
#         [ 79,  72,  93],
#         [ 82,  75,  96],
#         ...,
#         [ 92, 129, 173],
#         [ 94, 129, 173],
#         [ 91, 128, 172]],
#
#        ...,
#
#        [[248, 250, 250],
#         [253, 255, 255],
#         [246, 248, 248],
#         ...,
#         [167, 167, 167],
#         [170, 170, 170],
#         [169, 169, 169]],
#
#        [[250, 252, 252],
#         [253, 255, 255],
#         [241, 243, 243],
#         ...,
#         [158, 158, 158],
#         [162, 162, 162],
#         [163, 163, 163]],
#
#        [[251, 253, 253],
#         [252, 254, 254],
#         [238, 240, 240],
# ...

# %%
img.shape
# Out:
# (900, 900, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB => RGB
# OpenCv => BGR
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('./img.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap='gray')

# %%
img_gray
img_gray.shape
img_gray.min()
img_gray.max()
# Out:
# 255

# %%
plt.imshow(fix_img)
fix_img.shape
# Out:
# (900, 900, 3)

# %%
new_img = cv2.resize(fix_img,(300,600))
plt.imshow(new_img)

# %%
w_ratio = 0.5
h_ratio = 0.2
new_resize_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)
plt.imshow(new_resize_img)

# %%
new_resize_img.shape
# Out:
# (180, 450, 3)

# %%
new_img_flip = cv2.flip(fix_img,-1)
plt.imshow(new_img_flip)

# %%
cv2.imwrite('totally_new_img.jpg',fix_img)
# Out:
# True
