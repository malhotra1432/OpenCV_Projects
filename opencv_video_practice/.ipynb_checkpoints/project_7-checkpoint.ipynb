# %% [markdown]
# # Corner Detection

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flat_chess = cv2.imread('images/flat_chessboard.png')
flat_chess = cv2.cvtColor(flat_chess,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(flat_chess)

# %%
gray_flat_chess = cv2.cvtColor(flat_chess,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_flat_chess,cmap="gray")

# %%
real_chessboard = cv2.imread("images/real_chessboard.jpg")
real_chessboard = cv2.cvtColor(real_chessboard,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(real_chessboard)

# %%
gray_real_chessboard = cv2.cvtColor(real_chessboard,cv2.COLORBGR2GRAY)
plt.imshow(gray_real_chessboard,cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-48303acd8929> in <module>
# ----> 1 gray_real_chessboard = cv2.cvtColor(real_chessboard,cv2.COLORBGR2GRAY)
#       2 plt.imshow(gray_real_chessboard,cmap="gray")
#
# AttributeError: module 'cv2.cv2' has no attribute 'COLORBGR2GRAY'
